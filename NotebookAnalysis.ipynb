# %%
# %matplotlib inline
import CElegansFull_Notebook as CE
import numpy as np

# %%
inputMask = np.zeros(279)

# %%
inputMask[276] = 0.21
inputMask[278] = 0.21

# %%
(t, data, t_comp) = CE.run_Network(CE.Neuron, 0, 15.0, 0.01, inputMask, 1e-3)
# Out:
# CElegansFull_Notebook.py:123: RuntimeWarning: overflow encountered in exp
#   np.reciprocal(1.0 + np.exp(-B*(np.subtract(Vvec, Vth)))))

# %%
CE.plot_Colormap(data)

# %%
CE.plot_DominantModes(data, t)
