# %%
# %matplotlib inline
import CElegansFull_Notebook as CE
import numpy as np

# %%
(t, data, t_comp) = CE.run_Network(CE.Neuron, 0, 8.0, 0.01, 'PLM', 21000, 1e-3)
# Out:
# CElegansFull_Notebook.py:125: RuntimeWarning: overflow encountered in exp
#   np.reciprocal(1.0 + np.exp(-B*(np.subtract(Vvec, Vth)))))

# %%
CE.plot_Colormap(data)

# %%
CE.plot_DominantModes(data, t)
